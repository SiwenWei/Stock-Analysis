# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
import pandas_datareader as pdr

# %%
data=pdr.data.get_data_yahoo(['SU','IMO','ENB','CNQ'],start='2019-06-25',end='2019-07-24')

# %%
data.head()
# Out:
# Attributes       High                                         Low             \
# Symbols           CNQ        ENB        IMO         SU        CNQ        ENB
# Date
# 2019-06-25  27.980000  35.169998  28.070000  31.990000  27.549999  34.830002
# 2019-06-26  28.230000  35.169998  28.100000  31.940001  27.820000  34.700001
# 2019-06-27  27.889999  35.599998  28.049999  31.660000  26.770000  34.950001
# 2019-06-28  27.070000  36.099998  27.780001  31.389999  26.639999  35.549999
# 2019-07-01  27.549999  36.470001  28.190001  31.770000  26.740000  36.049999
#
# Attributes                         Open             ...        Close         \
# Symbols           IMO         SU    CNQ        ENB  ...          IMO     SU
# Date                                                ...
# 2019-06-25  27.600000  31.510000  27.59  35.099998  ...    27.639999  31.51
# 2019-06-26  27.610001  31.549999  27.82  34.990002  ...    27.910000  31.57
# ...

# %%
stock=data['Adj Close']
stock.head()
# Out:
# Symbols           CNQ        ENB        IMO     SU
# Date
# 2019-06-25  27.570000  34.840000  27.639999  31.51
# 2019-06-26  27.850000  35.060001  27.910000  31.57
# 2019-06-27  26.830000  35.540001  27.410000  31.09
# 2019-06-28  26.969999  36.080002  27.670000  31.16
# 2019-07-01  26.969999  36.169998  27.540001  31.60

# %%
data['2019-06']
# Out:
# Attributes       High                                         Low             \
# Symbols           CNQ        ENB        IMO         SU        CNQ        ENB
# Date
# 2019-06-25  27.980000  35.169998  28.070000  31.990000  27.549999  34.830002
# 2019-06-26  28.230000  35.169998  28.100000  31.940001  27.820000  34.700001
# 2019-06-27  27.889999  35.599998  28.049999  31.660000  26.770000  34.950001
# 2019-06-28  27.070000  36.099998  27.780001  31.389999  26.639999  35.549999
#
# Attributes                         Open             ...        Close         \
# Symbols           IMO         SU    CNQ        ENB  ...          IMO     SU
# Date                                                ...
# 2019-06-25  27.600000  31.510000  27.59  35.099998  ...    27.639999  31.51
# 2019-06-26  27.610001  31.549999  27.82  34.990002  ...    27.910000  31.57
# 2019-06-27  27.280001  31.000000  27.76  35.070000  ...    27.410000  31.09
# ...

# %%
data['Close'].plot(figsize=(15,5))

# %%
data.loc['2019-07','Close'].plot(figsize=(15,5))

# %%
data['Close']['SU'].pct_change().plot(figsize=(15,5),c='red') #daily Return=data[].pect_change()

# %%
data['Adj Close']['SU'].plot(figsize=(15,5),c='red')

# %%
sns.distplot(data['Adj Close']['SU'].pct_change().dropna(),bins=30,color='red')

# %%
sns.jointplot(stock['SU'],stock['IMO'],stock)

# %%
sns.pairplot(stock)
